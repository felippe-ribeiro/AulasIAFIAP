# %%
import pandas as pd

# %%
df = pd.read_excel("Frutas.xlsx")

# %%
df.head()
# Out:
#            Fruta  Calorias
# 0        Abacaxi        48
# 1          Amora        43
# 2        Abacate       160
# 3   Banana-prata        89
# 4  Banana-nanica        92

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['CategoriasFrutas'] = labelencoder.fit_transform(df['Fruta'])
df.head()
# Out:
#            Fruta  Calorias  CategoriasFrutas
# 0        Abacaxi        48                 1
# 1          Amora        43                 2
# 2        Abacate       160                 0
# 3   Banana-prata        89                 4
# 4  Banana-nanica        92                 3

# %%
#Criando classificação binária por categoria
df = pd.read_excel('Frutas.xlsx')
df.head()
# Out:
#            Fruta  Calorias
# 0        Abacaxi        48
# 1          Amora        43
# 2        Abacate       160
# 3   Banana-prata        89
# 4  Banana-nanica        92

# %%
dum_df = pd.get_dummies(df, columns=['Fruta'], dtype=int)
print(dum_df.dtypes)
print(dum_df)
# Out:
# Calorias               int64
# Fruta_Abacate          int64
# Fruta_Abacaxi          int64
# Fruta_Amora            int64
# Fruta_Banana-nanica    int64
# Fruta_Banana-prata     int64
# dtype: object
#    Calorias  Fruta_Abacate  Fruta_Abacaxi  Fruta_Amora  Fruta_Banana-nanica  \
# 0        48              0              1            0                    0
# 1        43              0              0            1                    0
# 2       160              1              0            0                    0
# 3        89              0              0            0                    0
# 4        92              0              0            0                    1
#
#    Fruta_Banana-prata
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
